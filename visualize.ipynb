# %%
import os
print(os.getcwd())  # Prints the working directory
# Out:
# C:\Users\v m kishore\OneDrive\PYTHON

# %%
path='C:/Users/v m kishore/OneDrive/D A T A'
os.chdir(path)

# %%
#plots
#load data using pandas DF
import pandas as pd

# %%
#loading glass data
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/glass/glass.data'
col_names = ['id','ri','na','mg','al','si','k','ca','ba','fe','glass_type']
glass = pd.read_csv(url, names=col_names, index_col='id')

# %%
glass.sort_values('al', inplace=True)
glass.head()
# Out:
#           ri     na    mg    al     si     k     ca   ba    fe  glass_type
# id
# 22   1.51966  14.77  3.75  0.29  72.02  0.03   9.00  0.0  0.00           1
# 185  1.51115  17.38  0.00  0.34  75.41  0.00   6.65  0.0  0.00           6
# 40   1.52213  14.21  3.82  0.47  71.77  0.11   9.57  0.0  0.00           1
# 39   1.52213  14.21  3.82  0.47  71.77  0.11   9.57  0.0  0.00           1
# 51   1.52320  13.72  3.72  0.51  71.75  0.09  10.06  0.0  0.16           1

# %%
#loading Drinks data
drink_cols = ['country', 'beer', 'spirit', 'wine', 'liters', 'continent']
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
drinks = pd.read_csv(url, header=0, names=drink_cols, na_filter=False)

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
#loading ufo data
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/ufo.csv'
ufo = pd.read_csv(url)
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['Time'] = pd.to_datetime(ufo.Time)   # changing to python datetime
ufo['Year'] = ufo.Time.dt.year           # Extracting Year from Time column 
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  Year
# 0 1930-06-01 22:00:00  1930
# 1 1930-06-30 20:00:00  1930
# 2 1931-02-15 14:00:00  1931
# 3 1931-06-01 13:00:00  1931
# 4 1933-04-18 19:00:00  1933

# %%
#loading beer data set
import pandas as pd
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt'
beer = pd.read_csv(url, sep=' ')
beer.head()
# Out:
#           name  calories  sodium  alcohol  cost
# 0    Budweiser       144      15      4.7  0.43
# 1      Schlitz       151      19      4.9  0.43
# 2    Lowenbrau       157      15      0.9  0.48
# 3  Kronenbourg       170       7      5.2  0.73
# 4     Heineken       152      11      5.0  0.77

# %%
#plotting data in 2D using seabros with MATPLOTLIB
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.5)
sns.lmplot(x='al', y='ri', data=glass, ci=None)

# %% [markdown]
# Glass Dataset information
# https://archive.ics.uci.edu/ml/datasets/Glass+Identification

# %%
#plotting data in 2D using pandas with MATPLOTLIB
glass.plot(kind='scatter', x='al', y='ri')

# %%
#Adding transparency 
glass.plot(kind='scatter', x='al', y='ri', alpha=0.3)

# %%
#scatter matrix
pd.scatter_matrix(drinks[['beer', 'spirit', 'wine']])
# Out:
# c:\python\python36\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E3D3AF6320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E3D3B17BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E3D3B48588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E3D3B6CFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E3D3B9AA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E3D3B9AAC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E3D3BECFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E3D3C1CA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E3D3C43518>]],
#       dtype=object)

# %%
#SM with Figure size
pd.scatter_matrix(drinks[['beer', 'spirit', 'wine']], figsize=(10, 8))
# Out:
# c:\python\python36\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E3D3D329B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E3D3D69710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E3E50A61D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E3E50CCC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E3E50FA710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E3E50FA748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001E3E514FC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E3E517F710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E3E51AE1D0>]],
#       dtype=object)

# %%
#Plotting categorical variables
drinks.continent.value_counts().plot(kind='bar')

# %%
#Plotting categorical variables
ufo.Year.value_counts().sort_index().plot()

# %%
#plot for numeric 
drinks.groupby('continent').mean().plot(kind='bar')

# %%
#Drop 1 col
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar')

# %%
#Stacked plot
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar', stacked=True)

# %%
df1=drinks.groupby('continent').mean().drop('liters', axis=1)

# %%
df1.head()
# Out:
#                  beer      spirit        wine
# continent
# AF          61.471698   16.339623   16.264151
# AS          37.045455   60.840909    9.068182
# EU         193.777778  132.555556  142.222222
# NA         145.434783  165.739130   24.521739
# OC          89.687500   58.437500   35.625000

# %%
df2=pd.DataFrame(df1.T)

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df3=df2.melt()

# %%
df3
# Out:
#    continent       value
# 0         AF   61.471698
# 1         AF   16.339623
# 2         AF   16.264151
# 3         AS   37.045455
# 4         AS   60.840909
# 5         AS    9.068182
# 6         EU  193.777778
# 7         EU  132.555556
# 8         EU  142.222222
# 9         NA  145.434783
# 10        NA  165.739130
# 11        NA   24.521739
# 12        OC   89.687500
# 13        OC   58.437500
# 14        OC   35.625000
# 15        SA  175.083333
# 16        SA  114.750000
# 17        SA   62.416667

# %%
from statsmodels.graphics.mosaicplot import mosaic
mosaic(df3['value'])
plt.show()

# %%
#boxplot 
drinks.spirit.plot(kind='box')

# %%
#Density plot
drinks.beer.plot(kind='density', xlim=(0, 500))

# %%
# HISTOGRAM plot 
# increase default figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
# add title and labels
drinks.beer.plot(kind='hist', bins=20, title='Histogram of Beer Servings')
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
# histogram of beer servings grouped by continent
drinks.hist(column='beer', by='continent')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000025955D62A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025955D7A2B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025955D9DD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025955DCC7F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025955DFB2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025955DFB2E8>]],
#       dtype=object)

# %%
#Share axis options
drinks.hist(column='beer', by='continent', sharex=True, sharey=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000025955E85160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025955F75358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025955F98A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025955FC9240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025955FEFA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025955FEFA58>]],
#       dtype=object)

# %%
# SCATTER plot using Matplotlib
plt.scatter(glass.al, glass.ri)
plt.xlabel('al')
plt.ylabel('ri')
# Out:
# Text(0,0.5,'ri')

# %%
import numpy as np
d = {'hipsize' :pd.Series([32,31,42,45,60,59]), 
     'Sholder' :pd.Series([41,40,46,45,46,47]), 
     'cluster' :pd.Series([1,1,2,2,3,3])}

df = pd.DataFrame(d)
colors = np.array(['red', 'green', 'blue', 'yellow'])
plt.scatter(df.hipsize,df.Sholder,c=colors[df.cluster], s=50)

# %%
#Other plots can be referred below  
http://matplotlib.org/users/screenshots.html

# %%
#SIMPLE plot for DENSITY and PREDECTION line.
# fit a linear regression model
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
feature_cols = ['al']
X = glass[feature_cols]
y = glass.ri
linreg.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# make predictions for all values of X
glass['ri_pred'] = linreg.predict(X)
glass.head()
plt.plot(glass.al, glass.ri_pred, color='red')
plt.xlabel('al')
plt.ylabel('Predicted ri')
# Out:
# Text(0,0.5,'Predicted ri')
